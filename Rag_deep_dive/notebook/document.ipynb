# %% [markdown]
# ## Data Ingestion

# %%
## document data structure

from langchain_core.documents import Document

# %%
doc = Document(
    page_content="this is the main text content I am using to create RAG",
    metadata={
        "source":"example.txt",
        "pages":1,
        "author":"kumar",
        "date_created":"2025-01-01"
    }
)
doc
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'author': 'kumar', 'date_created': '2025-01-01'}, page_content='this is the main text content I am using to create RAG')

# %%
## create a simple txt file
import os
os.makedirs("../data/text_files",exist_ok=True)

# %%
sample_texts = {
    "../data/text_files/machine_learning.txt":"""
# Machine Learning

## Definition

Machine Learning (ML) is a **branch of Artificial Intelligence (AI)** that enables computers to **learn patterns from data and make predictions or decisions without being explicitly programmed for every task**.

## Key Features

* **Data-Driven** – Learns patterns and relationships from data.
* **Automatic Learning** – Improves performance through experience and training.
* **Prediction** – Can predict future or unknown outcomes.
* **Pattern Recognition** – Identifies patterns and trends in data.
* **Generalization** – Applies learned patterns to new, unseen data.
* **Feature-Based Learning** – Uses relevant features from data to build models.
* **Model Training** – Learns from historical or training data.
* **Model Evaluation** – Measures performance using appropriate metrics.
* **Scalable** – Can work with large amounts of data.
* **Continuous Improvement** – Models can be retrained with new data to improve performance.
* **Multiple Learning Types** – Includes supervised, unsupervised, and reinforcement learning.
* **Wide Applications** – Used in recommendation systems, fraud detection, image recognition, NLP, healthcare, finance, and many other fields.

"""
}

for filepath,content in sample_texts.items():
    with open(filepath,'w',encoding="utf-8") as f:
        f.write(content)
print("machine learning file created!")
# Out:
# machine learning file created!

# %%
### text loaders

from langchain_community.document_loaders import TextLoader
loader = TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
document = loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='# Python\n\n## Definition\n\nPython is a **high-level, interpreted, general-purpose programming language** known for its simple, readable syntax. It is widely used in **web development, automation, data science, artificial intelligence, machine learning, and software testing**.\n\n## Key Features\n\n* **Simple & Readable** – Easy-to-understand syntax.\n* **High-Level Language** – Handles low-level details automatically.\n* **Interpreted** – Executes code without a separate compilation step.\n* **Dynamically Typed** – Variable types are determined at runtime.\n* **Object-Oriented** – Supports classes, objects, inheritance, polymorphism, etc.\n* **Cross-Platform** – Runs on Windows, Linux, and macOS.\n* **Open Source** – Free to use and supported by a large community.\n* **Large Library Ecosystem** – Provides extensive standard and third-party libraries.\n* **Multi-Paradigm** – Supports procedural, obje
# ...

# %%
## Directory loader
from langchain_community.document_loaders import DirectoryLoader

dir_loader = DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt",
    loader_cls=TextLoader,
    loader_kwargs={'encoding':"utf-8"},
    show_progress=False
)
document = dir_loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/machine_learning.txt'}, page_content='\n# Machine Learning\n\n## Definition\n\nMachine Learning (ML) is a **branch of Artificial Intelligence (AI)** that enables computers to **learn patterns from data and make predictions or decisions without being explicitly programmed for every task**.\n\n## Key Features\n\n* **Data-Driven** – Learns patterns and relationships from data.\n* **Automatic Learning** – Improves performance through experience and training.\n* **Prediction** – Can predict future or unknown outcomes.\n* **Pattern Recognition** – Identifies patterns and trends in data.\n* **Generalization** – Applies learned patterns to new, unseen data.\n* **Feature-Based Learning** – Uses relevant features from data to build models.\n* **Model Training** – Learns from historical or training data.\n* **Model Evaluation** – Measures performance using appropriate metrics.\n* **Scalable** – Can work with large amounts of data.\n* **Continuou
# ...

# %%
## pdf loader
from langchain_community.document_loaders import DirectoryLoader, PyMuPDFLoader
dir_loader = DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf",
    loader_cls=PyMuPDFLoader,
    # loader_kwargs={'encoding':'utf-8'},
    show_progress=False
)

pdf_document = dir_loader.load()
pdf_document
# Out:
# [Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-09-20T00:47:24+00:00', 'source': '../data/pdf/attention.pdf', 'file_path': '../data/pdf/attention.pdf', 'total_pages': 1, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-09-20T00:47:24+00:00', 'trapped': '', 'modDate': "D:20260920004724+00'00'", 'creationDate': "D:20260920004724+00'00'", 'page': 0}, page_content="Attention\nDefinition\nAttention is a technique that lets a model decide which parts of the input to focus on when producing\nan output, instead of treating every word equally.\nKey idea\nNot all words in a sentence matter equally for understanding a given word. Attention assigns a\nweight to every other word, showing how much it should be 'attended to' when processing the\ncurrent word.\nQuery, Key, Value\n•\nQuery (Q): what the current word is looking for.\n•\nKey (K): wh
# ...
